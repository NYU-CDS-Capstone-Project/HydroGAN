# %%
import numpy as np
import sys,os,h5py
f = h5py.File('D:/Documentos/fields_z=0.0.hdf5', 'r')
delta_HI = f['delta_HI'][:256,:256,:256]
#delta_m  = f['delta_m'][:1280]
f.close()
delta_HI.shape
# Out:
# (256, 256, 256)

# %%
delta_HI=np.array(delta_HI)
delta_HI
# Out:
# array([[[0.00000000e+00, 0.00000000e+00, 8.79255310e-02, ...,
#          2.04524845e-01, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.19025910e+00, 2.57088840e-01, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.49702442e-01, 2.92328328e-01, 1.35301664e-01],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 8.41070287e-05, 1.75185385e-04]],
#
#        [[0.00000000e+00, 0.00000000e+00, 1.65193766e-01, ...,
#          3.10567522e+00, 2.97084838e-01, 3.78623188e-01],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
# ...

# %%
f = h5py.File('D:/Documentos/fields_z=0.0.hdf5', 'r')
for n in range(2047,2048):
    print(f['delta_HI'][n].shape)
    a=f['delta_HI'][n]
# Out:
# (2048, 2048)

# %%
a[0][2047]
# Out:
# 0.022344368
